# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
! pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in c:\users\ben\appdata\local\enthought\canopy\edm\envs\user\lib\site-packages (19.2.3)

# %%
! pip install biopython
# Out:
# Requirement already satisfied: biopython in c:\users\ben\appdata\local\enthought\canopy\edm\envs\user\lib\site-packages (1.74)
# Requirement already satisfied: numpy in c:\users\ben\appdata\local\enthought\canopy\edm\envs\user\lib\site-packages (from biopython) (1.13.3)

# %%
from Bio import Entrez
import csv
import os


def search(query, number_of_results):
    Entrez.email = 'georgiamay.green@hotmail.co.uk'
    handle = Entrez.esearch(db='pubmed',
                            sort='relevance',
                            retmax=str(number_of_results),
                            retmode='xml',
                            term=query)
    search_results = Entrez.read(handle)
    return search_results


def fetch_details(list_of_ids):
    ids = ','.join(list_of_ids)
    Entrez.email = 'georgiamay.green@hotmail.co.uk'
    handle = Entrez.efetch(db='pubmed',
                           retmode='xml',
                           id=ids)
    query_results = Entrez.read(handle)
    return query_results


def pubmed_search(search_query: str, location: str, number_of_results: int):
    if not search_query:
        print("Please enter a search query.")
    else:
        if location:
            print("Searching PubMed for papers about {} near {}...".format(search_query.upper(), location.upper()))
        else:
            print("Searching PubMed for papers about {} in any location...".format(search_query.upper()))
        print()
        results = search(search_query, number_of_results)
        id_list = results["IdList"]
        papers = fetch_details(id_list)
        return_list = []
        if not location:
            for i, paper in enumerate(papers['PubmedArticle']):
                paper_data = {}
                print("Paper title: %s" % (paper['MedlineCitation']['Article']['ArticleTitle']))
                paper_data["title"] = paper['MedlineCitation']['Article']['ArticleTitle']
                paper_data["authors"] = []
                emails_found = False
                try:
                    testing = paper['MedlineCitation']['Article']['AuthorList']
                except KeyError:
                    continue
                for j in range(len(testing)):
                    email = None
                    author_reference = None
                    if len(paper['MedlineCitation']['Article']['AuthorList'][j]['AffiliationInfo']) != 0:
                        affiliation = paper['MedlineCitation']['Article']['AuthorList'][j]['AffiliationInfo'][0][
                            'Affiliation']
                        split_affiliation = paper['MedlineCitation']['Article']['AuthorList'][j]['AffiliationInfo'][0][
                            'Affiliation'].split()
                        for word in split_affiliation:
                            if "@" in word:
                                email = word
                                if email.endswith("."):
                                    email = email[:-1]
                                author_reference = affiliation
                                emails_found = True
                        if email:
                            try:
                                firstname = paper['MedlineCitation']['Article']['AuthorList'][j]['ForeName']
                                lastname = paper['MedlineCitation']['Article']['AuthorList'][j]['LastName']
                                print("Author name: {} {}".format(firstname, lastname))
                            except KeyError:
                                firstname = "unknown"
                                lastname = "unknown"
                                print('Author name could not be found')
                            print("Author email: {}".format(email))
                            print("Author reference: {}".format(author_reference))
                            paper_data["authors"].append(
                                {"first": firstname,
                                 "last": lastname,
                                 "email": email,
                                 "reference": author_reference}
                            )
                return_list.append(paper_data)
                if not emails_found:
                    print("No email addresses associated with this paper.")
                print()
        if location:
            for i, paper in enumerate(papers['PubmedArticle']):
                paper_data = {}
                relevant_emails_found = False
                paper_title = False
                paper_data["title"] = paper['MedlineCitation']['Article']['ArticleTitle']
                paper_data["authors"] = []
                try:
                    testing = paper['MedlineCitation']['Article']['AuthorList']
                except KeyError:
                    continue
                for j in range(len(testing)):
                    email = None
                    author_reference = None
                    if len(paper['MedlineCitation']['Article']['AuthorList'][j]['AffiliationInfo']) != 0:
                        affiliation = paper['MedlineCitation']['Article']['AuthorList'][j]['AffiliationInfo'][0][
                            'Affiliation']
                        split_affiliation = affiliation.split()
                        if location.lower() in affiliation.lower():
                            if not paper_title:
                                print("Paper title: %s" % (paper['MedlineCitation']['Article']['ArticleTitle']))
                                paper_title = True
                            for word in split_affiliation:
                                if "@" in word:
                                    email = word
                                    if email.endswith("."):
                                        email = email[:-1]
                                    author_reference = affiliation
                                    relevant_emails_found = True
                            if email:
                                try:
                                    firstname = paper['MedlineCitation']['Article']['AuthorList'][j]['ForeName']
                                    lastname = paper['MedlineCitation']['Article']['AuthorList'][j]['LastName']
                                    print("Author name: {} {}".format(firstname, lastname))
                                except KeyError:
                                    firstname = "unknown"
                                    lastname = "unknown"
                                    print('Author name could not be found')
                                print("Author email: {}".format(email))
                                print("Author reference: {}".format(author_reference))
                                paper_data["authors"].append(
                                    {"first": firstname,
                                     "last": lastname,
                                     "email": email,
                                     "reference": author_reference}
                                )
                return_list.append(paper_data)
                if not relevant_emails_found and paper_title:
                    print("No email addresses associated with this paper.")
                if paper_title:
                    print()
        print("Search complete.")
        print()
        return return_list


def scrape_pubmed(query_list):
    current_query = ""
    current_location = ""
    with open(query_list, 'r') as list_of_queries:
        with open("pubmed_emails.csv", "w") as output:
            writer = csv.writer(output)
            writer.writerow(["pubmed query",
                             "location filter",
                             "paper title",
                             "author first name",
                             "author last name",
                             "author email",
                             "author reference"])
            queries = list_of_queries.readlines()
            last = queries[-1]
            for line in queries:
                if line != last and line != "\n":
                    if not current_query:
                        current_query = line[:-1]
                    else:
                        current_location = line[:-1]
                else:
                    if line == last:
                        if current_query:
                            current_location = line
                        else:
                            current_query = line
                    results_list = pubmed_search(current_query, current_location, 1000)
                    for paper_info in results_list:
                        for author in paper_info["authors"]:
                            add_to_file = [
                                current_query,
                                current_location,
                                paper_info["title"],
                                author["first"],
                                author["last"],
                                author["email"],
                                author["reference"]]
                            try:
                                writer.writerow(add_to_file)
                            except UnicodeEncodeError:
                                continue
                    current_query = ""
                    current_location = ""
    print("ALL SEARCHES COMPLETE")
    output_location = os.path.join(os.getcwd(), "pubmed_emails.csv")
    print("Results written to {}".format(output_location))

# %% [markdown]
# Before attempting to run this program, go to the top of the page and click the box which says "%pylab inline". Press Shift+Enter repeatedly until you reach the box starting with "def main():".
#
# In the queries.txt file in the same file as this iPython notebook, enter the queries you want to use. If you want to filter a query by location, enter the location in the line underneath the query. Remember to separate queries with an empty line.
#
# Then press Shift+Enter on the box below, and all your queries will run. They will be printed below, and also saved to a spreadsheet called pubmed_emails.csv in the same folder as this notebook and the queries.txt file, along with some associated metadata.

# %%
def main():
    scrape_pubmed("queries.txt")


if __name__ == "__main__":
    main()
# Out:
# Searching PubMed for papers about METASTASIS near LONDON...
#
# Paper title: Molecular Mechanisms of Breast Cancer Metastasis to the Lung: Clinical and Experimental Perspectives.
# Author name: Braeden Medeiros
# Author email: bmedeir4@uwo.ca
# Author reference: London Regional Cancer Program, London Health Sciences Centre, Department of Anatomy & Cell Biology, Western University, London, ON N6A 5W9, Canada. bmedeir4@uwo.ca.
# Author name: Alison L Allan
# Author email: alison.allan@lhsc.on.ca
# Author reference: London Regional Cancer Program, London Health Sciences Centre, Departments of Anatomy & Cell Biology and Oncology, Western University, London, ON N6A 5W9, Canada. alison.allan@lhsc.on.ca.
#
# Paper title: Translational models of prostate cancer bone metastasis.
# Author name: Hon S Leong
# Author email: leong.hon@mayo.edu
# Author reference: Department of Surgery, Division of Urology, Schulich School of Medicine and Dentistry, University of Western Ontario, London, Ontario, Canada. leong.hon@mayo.edu.
#
# Paper title: Experimental evidence of Migfilin as a new therapeutic target of hepatocellular carcinoma metastasis.
# No email addresses associated with this paper.
#
# Paper title: CD15s/CD62E Interaction Mediates the Adhesion of Non-Small Cell Lung Cancer Cells on Brain Endothelial Cells: Implications for Cerebral Metastasis.
# Author name: Keyoumars Ashkan
# Author email: k.ashkan@nhs.net
# Author reference: Neuro-Surgery, King's College Hospital, Denmark Hill, London SE5 9RS, UK. k.ashkan@nhs.net.
#
# Paper title: Apalutamide Treatment and Metastasis-free Survival in Prostate Cancer.
# No email addresses associated with this paper.
#
# Paper title: p62/SQSTM1 interacts with vimentin to enhance breast cancer metastasis.
# No email addresses associated with this paper.
#
# Paper title: Invasion and metastasis--recent advances and future challenges.
# Author name: Ann F Chambers
# Author email: ann.chambers@Lhsc.on.ca
# Author reference: London Regional Cancer Program, 790 Commissioners Road East, London, Ontario, N6A 4L6, Canada, ann.chambers@Lhsc.on.ca.
#
# Paper title: Chromosomal instability drives metastasis through a cytosolic DNA response.
# No email addresses associated with this paper.
#
# Paper title: Generation and characterisation of two D2A1 mammary cancer sublines to model spontaneous and experimental metastasis in a syngeneic BALB/c host.
# Author name: Ute Jungwirth
# Author email: clare.isacke@icr.ac.uk
# Author reference: The Breast Cancer Now Toby Robins Research Centre, The Institute of Cancer Research, 237 Fulham Road, London, SW3 6JB, UK ute.jungwirth@icr.ac.uk clare.isacke@icr.ac.uk.
# Author name: Clare M Isacke
# Author email: clare.isacke@icr.ac.uk
# Author reference: The Breast Cancer Now Toby Robins Research Centre, The Institute of Cancer Research, 237 Fulham Road, London, SW3 6JB, UK ute.jungwirth@icr.ac.uk clare.isacke@icr.ac.uk.
#
# Paper title: Deep sequencing reveals the mitochondrial DNA variation landscapes of breast-to-brain metastasis blood samples.
# No email addresses associated with this paper.
#
# Paper title: Epithelial-to-mesenchymal transition leads to disease-stage differences in circulating tumor cell detection and metastasis in pre-clinical models of prostate cancer.
# No email addresses associated with this paper.
#
# Paper title: Pericyte-fibroblast transition promotes tumor growth and metastasis.
# No email addresses associated with this paper.
#
# Paper title: Nanoparticles coated with the tumor-penetrating peptide iRGD reduce experimental breast cancer metastasis in the brain.
# Author name: Amanda M Hamilton
# Author email: hamilton@robarts.ca
# Author reference: Robarts Research Institute, University of Western Ontario, 1151 Richmond St N, London, ON, N6A 5B7, Canada. hamilton@robarts.ca.
#
# Paper title: C/EBPα Short-Activating RNA Suppresses Metastasis of Hepatocellular Carcinoma through Inhibiting EGFR/β-Catenin Signaling Mediated EMT.
# No email addresses associated with this paper.
#
# Search complete.
#
# Searching PubMed for papers about SLEEP APNOEA in any location...
#
# Paper title: Management of Sleep Apnea Syndromes in Heart Failure.
# Author name: Bernardo J Selim
# Author email: Selim.bernardo@mayo.edu
# Author reference: Division of Pulmonary and Critical Care Medicine, Mayo Clinic Center for Sleep Medicine, Mayo Clinic, 200 First Street Southwest, Rochester, MN 55905, USA. Electronic address: Selim.bernardo@mayo.edu.
#
# Paper title: Sleep Apnea and Cardiovascular Disease: Lessons From Recent Trials and Need for Team Science.
# Author name: Luciano F Drager
# Author email: sredline1@rics.bwh.harvard.edu
# Author reference: From Hypertension Unit (L.F.D.) and Sleep Laboratory, Pulmonary Division (G.L.-F.), Instituto do Coracao, and Hypertension Unit, Renal Division (L.F.D.), University of São Paulo Medical School, Brazil; Adelaide Institute for Sleep Health, College of Medicine and Public Health, and School of Medicine, Faculty of Medicine, Nursing, and Health Sciences, Flinders University, Australia (R.D.M.); Sleep Health Service, Respiratory and Sleep Services, Southern Adelaide Local Health Network, Australia (R.D.M.); Respiratory Department, Institut de Recerca Biomèdica de Lleida, Lleida and Centro de Investigacion Biomedica en Red de Enfermedades Respiratorias, Madrid, Spain (F.B.); and Division of Sleep and Circadian Disorders, Brigham and Women's Hospital and Harvard Medical School, Boston, MA (S.R.). luciano.drager@incor.usp.br sredline1@rics.bwh.harvard.edu.
# Author name: Susan Redline
# Author email: sredline1@rics.bwh.harvard.edu
# Author reference: From Hypertension Unit (L.F.D.) and Sleep Laboratory, Pulmonary Division (G.L.-F.), Instituto do Coracao, and Hypertension Unit, Renal Division (L.F.D.), University of São Paulo Medical School, Brazil; Adelaide Institute for Sleep Health, College of Medicine and Public Health, and School of Medicine, Faculty of Medicine, Nursing, and Health Sciences, Flinders University, Australia (R.D.M.); Sleep Health Service, Respiratory and Sleep Services, Southern Adelaide Local Health Network, Australia (R.D.M.); Respiratory Department, Institut de Recerca Biomèdica de Lleida, Lleida and Centro de Investigacion Biomedica en Red de Enfermedades Respiratorias, Madrid, Spain (F.B.); and Division of Sleep and Circadian Disorders, Brigham and Women's Hospital and Harvard Medical School, Boston, MA (S.R.). luciano.drager@incor.usp.br sredline1@rics.bwh.harvard.edu.
#
# Paper title: Sleep Apnea and Kidney Function Trajectory: Results From a 20-Year Longitudinal Study of Healthy Middle-Aged Adults.
# No email addresses associated with this paper.
#
# Paper title: Childhood Health and Educational Outcomes Associated With Maternal Sleep Apnea: A Population Record-Linkage Study.
# No email addresses associated with this paper.
#
# Paper title: Prevalence, Severity, and Prognostic Value of Sleep Apnea Syndromes in Cardiac Amyloidosis.
# No email addresses associated with this paper.
#
# Paper title: A systematic comparison of factors that could impact treatment recommendations for patients with Positional Obstructive Sleep Apnea (POSA).
# Author name: Daniel J Levendowski
# Author email: dan@b-alert.com
# Author reference: Advanced Brain Monitoring, Carlsbad, CA, USA. Electronic address: dan@b-alert.com.
#
# Paper title: Damage of Inner Ear Sensory Hair Cells via Mitochondrial Loss in a Murine Model of Sleep Apnea With Chronic Intermittent Hypoxia.
# No email addresses associated with this paper.
#
# Paper title: Sleep Apnea and Obstructive Airway Disease in Older Men: Outcomes of Sleep Disorders in Older Men Study.
# No email addresses associated with this paper.
#
# Paper title: A Retrospective Study to Compare the Use of the Mean Apnea-Hypopnea Duration and the Apnea-Hypopnea Index with Blood Oxygenation and Sleep Patterns in Patients with Obstructive Sleep Apnea Diagnosed by Polysomnography.
# No email addresses associated with this paper.
#
# Paper title: Sleep apnea: State of the art.
# Author name: Martin R Cowie
# Author email: m.cowie@imperial.ac.uk
# Author reference: Imperial College London, Royal Brompton Hospital, United Kingdom. Electronic address: m.cowie@imperial.ac.uk.
#
# Paper title: Treatment of sleep apnea in patients with paroxysmal atrial fibrillation: design and rationale of a randomized controlled trial.
# No email addresses associated with this paper.
#
# Paper title: Sleep Apnea-Predictor of Functional Outcome in Acute Ischemic Stroke.
# Author name: Radhika Nair
# Author email: radhu1685@yahoo.co.in
# Author reference: Department of Neurology, KMC Manipal, Karnataka, India. Electronic address: radhu1685@yahoo.co.in.
#
# Paper title: Evaluation of a Commercial Ballistocardiography Sensor for Sleep Apnea Screening and Sleep Monitoring.
# Author name: Dorien Huysmans
# Author email: dorien.huysmans@esat.kuleuven.be
# Author reference: KU Leuven, Department of Electrical Engineering (ESAT), STADIUS Center for Dynamical Systems, Signal Processing, and Data Analytics, 3000 Leuven, Belgium. dorien.huysmans@esat.kuleuven.be.
# Author name: Pascal Borzée
# Author email: pascal.borzee@uzleuven.be
# Author reference: UZ Leuven, Department of Pneumology, 3000 Leuven, Belgium. pascal.borzee@uzleuven.be.
# Author name: Dries Testelmans
# Author email: dries.testelmans@uzleuven.be
# Author reference: UZ Leuven, Department of Pneumology, 3000 Leuven, Belgium. dries.testelmans@uzleuven.be.
# Author name: Bertien Buyse
# Author email: bertien.buyse@uzleuven.be
# Author reference: UZ Leuven, Department of Pneumology, 3000 Leuven, Belgium. bertien.buyse@uzleuven.be.
# Author name: Tim Willemen
# Author email: tim.willemen@equilli.com
# Author reference: Equilli, 2800 Mechelen, Belgium. tim.willemen@equilli.com.
# Author name: Sabine Van Huffel
# Author email: sabine.vanhuffel@esat.kuleuven.be
# Author reference: KU Leuven, Department of Electrical Engineering (ESAT), STADIUS Center for Dynamical Systems, Signal Processing, and Data Analytics, 3000 Leuven, Belgium. sabine.vanhuffel@esat.kuleuven.be.
# Author name: Carolina Varon
# Author email: carolina.varon@esat.kuleuven.be
# Author reference: KU Leuven, Department of Electrical Engineering (ESAT), STADIUS Center for Dynamical Systems, Signal Processing, and Data Analytics, 3000 Leuven, Belgium. carolina.varon@esat.kuleuven.be.
#
# Paper title: Symptomless Multi-Variable Apnea Prediction Index Assesses Obstructive Sleep Apnea Risk and Adverse Outcomes in Elective Surgery.
# No email addresses associated with this paper.
#
# Paper title: A review of the associations between obstructive sleep apnea and hypertensive disorders of pregnancy and possible mechanisms of disease.
# Author name: Jennifer E Dominguez
# Author email: Jennifer.dominguez@dm.duke.edu
# Author reference: Duke Department of Anesthesiology, Durham, NC, 27710, USA. Electronic address: Jennifer.dominguez@dm.duke.edu.
#
# Paper title: Screening for High Risk of Sleep Apnea in an Ambulatory Care Setting in Saudi Arabia.
# Author name: Adeel Nazir Ahmad
# Author email: adeelnahmad@gmail.com
# Author reference: Department of Family Medicine, King Faisal Specialist Hospital and Research Centre, Jeddah 40047, Saudi Arabia. adeelnahmad@gmail.com.
# Author name: Geraldine McLeod
# Author email: geri.mcleod@otago.ac.nz
# Author reference: Christchurch Health and Development Study, Department of Psychological Medicine, University of Otago, Christchurch 8011, New Zealand. geri.mcleod@otago.ac.nz.
# Author name: Nada Al Zahrani
# Author email: nal-zahrani1@kfshrc.edu.sa
# Author reference: Department of Family Medicine, King Faisal Specialist Hospital and Research Centre, Jeddah 40047, Saudi Arabia. nal-zahrani1@kfshrc.edu.sa.
# Author name: Haneen Al Zahrani
# Author email: haneen788@gmail.com
# Author reference: Department of Family Medicine, King Faisal Specialist Hospital and Research Centre, Jeddah 40047, Saudi Arabia. haneen788@gmail.com.
#
# Paper title: [Comorbidities of heart failure: sleep apnea].
# Author name: M Arzt
# Author email: michael.arzt@klinik.uni-regensburg.de
# Author reference: Schlafmedizinisches Zentrum, Klinik und Poliklinik für Innere Medizin II, Universitätsklinikum Regensburg, Franz-Josef-Strauß-Allee 11, 93053, Regensburg, Deutschland. michael.arzt@klinik.uni-regensburg.de.
#
# Paper title: Upper Airway Stimulation for Obstructive Sleep Apnea: Durability of the Treatment Effect at 18 Months.
# No email addresses associated with this paper.
#
# Paper title: Temporal relationship of sleep apnea and acromegaly: a nationwide study.
# Author name: Konstantina Vouzouneraki
# Author email: konstantina.vouzouneraki@umu.se
# Author reference: Department of Public Health and Clinical Medicine, Umeå University, Umeå, Sweden. konstantina.vouzouneraki@umu.se.
#
# Paper title: Sleep apnea, metabolic disease, and the cutting edge of therapy.
# Author name: Matthew Light
# Author email: mlight@ucsd.edu
# Author reference: Division of Pulmonary, Critical Care, and Sleep Medicine, UC San Diego Department of Medicine, La Jolla, CA, United States. Electronic address: mlight@ucsd.edu.
# Author name: Karen McCowen
# Author email: kmccowen@ucsd.edu
# Author reference: Division of Endocrinology, UC San Diego Department of Medicine, La Jolla, CA, United States. Electronic address: kmccowen@ucsd.edu.
# Author name: Atul Malhotra
# Author email: amalhotra@ucsd.edu
# Author reference: Division of Pulmonary, Critical Care, and Sleep Medicine, UC San Diego Department of Medicine, La Jolla, CA, United States. Electronic address: amalhotra@ucsd.edu.
# Author name: Omar A Mesarwi
# Author email: omesarwi@ucsd.edu
# Author reference: Division of Pulmonary, Critical Care, and Sleep Medicine, UC San Diego Department of Medicine, La Jolla, CA, United States. Electronic address: omesarwi@ucsd.edu.
#
# Paper title: Sleep Apnea Research in Animals. Past, Present, and Future.
# No email addresses associated with this paper.
#
# Paper title: Targeting volume overload and overnight rostral fluid shift: A new perspective to treat sleep apnea.
# Author name: Elisa Perger
# Author email: elisaperger@hotmail.com
# Author reference: AP-HP, Groupe Hospitalier Pitié-Salpêtrière Charles Foix, Service de Pathologies du Sommeil du Département R3S, F-75013, Paris, France. Electronic address: elisaperger@hotmail.com.
#
# Paper title: [Association between mixed sleep apnea and treatment-emergent central sleep apnea].
# No email addresses associated with this paper.
#
# Paper title: The OXIMAPA Study: Hypertension Control by ABPM and Association with Sleep Apnea Syndrome by Pulse Oximetry.
# No email addresses associated with this paper.
#
# Paper title: Implantable cardioverter-defibrillator-computed respiratory disturbance index accurately identifies severe sleep apnea: The DASAP-HF study.
# Author name: Luigi Padeletti
# Author email: lpadeletti@interfree.it
# Author reference: IRCCS MultiMedica, Sesto San Giovanni, Milan, Italy. Electronic address: lpadeletti@interfree.it.
#
# Paper title: Cardioversion of atrial fibrillation does not affect obstructive sleep apnea.
# No email addresses associated with this paper.
#
# Paper title: Comparison of positional and rapid eye movement-dependent sleep apnea syndromes.
# No email addresses associated with this paper.
#
# Paper title: Sleep apnea may be associated with suicidal ideation in adolescents.
# Author name: Po-Hsiu Kuo
# Author email: phkuo@ntu.edu.tw
# Author reference: Department of Public Health and Institute of Epidemiology and Preventive Medicine, College of Public Health, National Taiwan University, 17, Xuzhou Rd., Taipei, Taiwan. phkuo@ntu.edu.tw.
#
# Paper title: Sleep apnea and femoral neck BMD among Singaporean mid-life women.
# Author name: Eu Leong Yong
# Author email: eu_leong_yong@nuhs.edu.sg
# Author reference: Department of Obstetrics and Gynecology, National University of Singapore, 1E, Road, Tower Block Level 12, Kent Ridge, 119228, Singapore. eu_leong_yong@nuhs.edu.sg.
#
# Paper title: Women with symptoms of sleep-disordered breathing are less likely to be diagnosed and treated for sleep apnea than men.
# Author name: Eva Lindberg
# Author email: eva.lindberg@medsci.uu.se
# Author reference: Department of Medical Sciences, Respiratory, Allergy and Sleep Research, Uppsala University, Sweden. Electronic address: eva.lindberg@medsci.uu.se.
#
# Paper title: Sleep Apnea and Circadian Extracellular Fluid Change as Independent Factors for Nocturnal Polyuria.
# Author name: Yasuhiro Yamaguchi
# Author email: yamayasu-tky@umin.ac.jp
# Author reference: Department of Geriatric Medicine, Graduate School of Medicine, University of Tokyo, Tokyo, Japan. Electronic address: yamayasu-tky@umin.ac.jp.
#
# Paper title: Economic Assessment of 4 Approaches to the Diagnosis and Initial Treatment of Sleep Apnea.
# Author name: Dawn M Bravata
# Author email: dawn.bravata2@va.gov
# Author reference: Veterans Affairs Center for Applied Systems Engineering (VA-CASE), Indianapolis, Indiana. dawn.bravata2@va.gov.
#
# Paper title: Symptoms of Daytime Sleepiness and Sleep Apnea in Liver Cirrhosis Patients.
# No email addresses associated with this paper.
#
# Paper title: Diagnosis and treatment of epilepsy and sleep apnea comorbidity.
# No email addresses associated with this paper.
#
# Paper title: Prevalence of sleep apnea at the acute phase of ischemic stroke with or without thrombolysis.
# Author name: Jaana K Huhtakangas
# Author email: jaana.huhtakangas@ppshp.fi
# Author reference: Respiratory Medicine Unit, Institute of Clinical Medicine, Oulu University Hospital, Finland. Electronic address: jaana.huhtakangas@ppshp.fi.
#
# Paper title: Sleep apnea and subsequent cancer incidence.
# Author name: Arthur Sillah
# Author email: asillah@uw.edu
# Author reference: Department of Epidemiology, University of Washington School of Public Health, Seattle, WA, USA. asillah@uw.edu.
#
# Paper title: Association of sleep apnea and sleep duration with peripheral artery disease: The Multi-Ethnic Study of Atherosclerosis (MESA).
# Author name: Mako Nagayoshi
# Author email: mnagayoshi@nagasaki-u.ac.jp
# Author reference: Division of Epidemiology & Community Health, University of Minnesota, Minneapolis, MN, USA; Department of Community Medicine, Nagasaki University Graduate School of Biomedical Science, Nagasaki, Japan. Electronic address: mnagayoshi@nagasaki-u.ac.jp.
#
# Paper title: Treating sleep apnea in Parkinson's disease with C-PAP: feasibility concerns and effects on cognition and alertness.
# Author name: Michele Terzaghi
# Author email: michele.terzaghi@mondino.it
# Author reference: Unit of Sleep Medicine and Epilepsy, C. Mondino National Neurological Institute, Pavia, Italy. Electronic address: michele.terzaghi@mondino.it.
#
# Paper title: Managing comorbid cardiovascular disease and sleep apnea with pharmacotherapy.
# No email addresses associated with this paper.
#
# Paper title: Effect of strength training on sleep apnea severity in the elderly: study protocol for a randomized controlled trial.
# Author name: Roberto Pacheco da Silva
# Author email: roberto.pacheco01@gmail.com
# Author reference: Graduate Program in Cardiology and Cardiovascular Sciences, Universidade Federal do Rio Grande do Sul (UFRGS), Porto Alegre, RS, Brazil. roberto.pacheco01@gmail.com.
#
# Paper title: Sleep apnea and the risk of chronic kidney disease: a nationwide population-based cohort study.
# No email addresses associated with this paper.
#
# Paper title: The effect of acetazolamide on sleep apnea at high altitude: a systematic review and meta-analysis.
# No email addresses associated with this paper.
#
# Paper title: Sleep Apnea and Cardiovascular Disease: An Enigmatic Risk Factor.
# Author name: John S Floras
# Author email: john.floras@utoronto.ca
# Author reference: From the University Health Network and Sinai Health System Division of Cardiology, Department of Medicine, University of Toronto, Ontario, Canada. john.floras@utoronto.ca.
#
# Paper title: Is sleep apnea underdiagnosed in adult patients with osteogenesis imperfecta? -a single-center cross-sectional study.
# Author name: Heidi Arponen
# Author email: heidi.arponen@helsinki.fi
# Author reference: Department of Oral and Maxillofacial Diseases, University of Helsinki, P.O. Box 41, FI-00014, Helsinki, Finland. heidi.arponen@helsinki.fi.
#
# Paper title: Wavelet analysis of oximetry recordings to assist in the automated detection of moderate-to-severe pediatric sleep apnea-hypopnea syndrome.
# No email addresses associated with this paper.
#
# Paper title: Sleep apnea and risk of vertigo: A nationwide population-based cohort study.
# No email addresses associated with this paper.
#
# Paper title: Sleep-Disordered Breathing, Orofacial Growth, and Prevention of Obstructive Sleep Apnea.
# Author name: Christian Guilleminault
# Author email: cguil@stanford.edu
# Author reference: Division of Sleep Medicine, Stanford University, 450 Broadway Pavillion C 2nd Floor, Redwood City, CA 94063, USA. Electronic address: cguil@stanford.edu.
#
# Paper title: Association between sleep apnea and low bone mass in adults: a systematic review and meta-analysis.
# Author name: H Eimar
# Author email: Eimar@ualberta.ca
# Author reference: School of Dentistry, Faculty of Medicine & Dentistry, University of Alberta, Edmonton, AB, T6G 1C9, Canada. Eimar@ualberta.ca.
#
# Paper title: Sleep Apnea: Types, Mechanisms, and Clinical Cardiovascular Consequences.
# Author name: Shahrokh Javaheri
# Author email: shahrokhjavaheri@icloud.com
# Author reference: Pulmonary and Sleep Division, Bethesda North Hospital, Cincinnati, Ohio. Electronic address: shahrokhjavaheri@icloud.com.
#
# Paper title: Incidence of children at risk for obstructive sleep apnea undergoing common day surgery procedures.
# Author name: Warren K Yunker
# Author email: warren.yunker@ahs.ca
# Author reference: Department of Surgery, Divisions of Otolaryngology and Pediatric Surgery, Cumming School of Medicine, Alberta Children's Hospital, University of Calgary, Calgary, Alberta, Canada. Electronic address: warren.yunker@ahs.ca.
#
# Paper title: A Sleep Position Trainer for positional sleep apnea: a randomized, controlled trial.
# No email addresses associated with this paper.
#
# Paper title: Sleep apnea and pesticide exposure in a study of US farmers.
# Author name: Stephanie J London
# Author email: london2@niehs.nih.gov
# Author reference: Epidemiology Branch, National Institute of Environmental Health Sciences, National Institutes of Health, Department of Health and Human Services, Research Triangle Park, NC, USA. Electronic address: london2@niehs.nih.gov.
#
# Paper title: Evaluation of the association between sleep apnea and polyunsaturated fatty acids profiles in patients after percutaneous coronary intervention.
# Author name: Kentaro Jujo
# Author email: juken1123@mac.com
# Author reference: Department of Cardiology, Tokyo Women's Medical University, 8-1 Kawadacho, Shinjuku-ku, Tokyo, 162-0054, Japan. juken1123@mac.com.
#
# Paper title: Sleep Apnea Is a Risk Factor for Stroke and Vascular Dementia.
# Author name: Antonio Culebras
# Author email: culebraa@upstate.edu
# Author reference: Department of Neurology, SUNY Upstate Medical University, 750 E. Adams Street, Syracuse, NY, 13210, USA. culebraa@upstate.edu.
#
# Paper title: Addition of frontal EEG to adult home sleep apnea testing: does a more accurate determination of sleep time make a difference?
# Author name: Matthew P Light
# Author email: mlight@ucsd.edu
# Author reference: Division of Pulmonary, Critical Care, and Sleep Medicine, New York University School of Medicine, New York, NY, USA. mlight@ucsd.edu.
#
# Paper title: Impact of sleep apnea syndrome on survival in patients with multiple system atrophy.
# Author name: Wassilios G Meissner
# Author email: wassilios.meissner@chu-bordeaux.fr
# Author reference: Service de Neurologie, CHU de Bordeaux, F-33076 Bordeaux, France; Univ. de Bordeaux, Institut des Maladies Neurodégénératives, UMR 5293, F-33000 Bordeaux, France; CNRS, Institut des Maladies Neurodégénératives, UMR 5293, F-33000 Bordeaux, France; Centre de référence atrophie multisystématisée, CHU de Bordeaux, F-33076 Bordeaux, France. Electronic address: wassilios.meissner@chu-bordeaux.fr.
#
# Paper title: Diagnosis of sleep apnea in patients with stable chronic heart failure using a portable sleep test diagnostic device.
# Author name: Inês Araújo
# Author email: inesarauj@gmail.com
# Author reference: Heart Failure Unit, Internal Medicine Department, Hospital de São Francisco Xavier, Centro Hospitalar Lisboa Ocidental (CHLO), Estrada do Forte do Alto do Duque, 1449-005, Lisbon, Portugal. inesarauj@gmail.com.
#
# Paper title: [Complex sleep apnea syndrome].
# No email addresses associated with this paper.
#
# Paper title: Treatment of sleep apnea with a combination of a carbonic anhydrase inhibitor and an aldosterone antagonist: a patent evaluation of CA2958110 and IN6616DEN2012.
# No email addresses associated with this paper.
#
# Paper title: Association of Positive Airway Pressure With Cardiovascular Events and Death in Adults With Sleep Apnea: A Systematic Review and Meta-analysis.
# No email addresses associated with this paper.
#
# Paper title: Sleep, sleep apnea and atrial fibrillation: Questions and answers.
# Author name: Younghoon Kwon
# Author email: yk2j@hscmail.mcc.virginia.edu
# Author reference: Division of Cardiovascular Medicine, Department of Medicine and Department of Sleep Medicine, University of Virginia, Charlottesville, VA, USA. Electronic address: yk2j@hscmail.mcc.virginia.edu.
#
# Paper title: Complementary roles of gasotransmitters CO and H2S in sleep apnea.
# Author name: Solomon H Snyder
# Author email: ssnyder@jhmi.edu
# Author reference: Department of Neuroscience, Johns Hopkins University School of Medicine, Baltimore, MD 21205; nanduri@uchicago.edu ssnyder@jhmi.edu.
# Author name: Nanduri R Prabhakar
# Author email: ssnyder@jhmi.edu
# Author reference: Institute of Integrative Physiology, Biological Sciences Division, University of Chicago, Chicago, IL 60637; nanduri@uchicago.edu ssnyder@jhmi.edu.
#
# Paper title: Breathing Disturbances Without Hypoxia Are Associated With Objective Sleepiness in Sleep Apnea.
# No email addresses associated with this paper.
#
# Paper title: Sleep Apnea, Sleep Duration and Brain MRI Markers of Cerebral Vascular Disease and Alzheimer's Disease: The Atherosclerosis Risk in Communities Study (ARIC).
# No email addresses associated with this paper.
#
# Paper title: Whole Genome DNA Methylation Analysis of Obstructive Sleep Apnea: IL1R2, NPR2, AR, SP140 Methylation and Clinical Phenotype.
# No email addresses associated with this paper.
#
# Paper title: Adaptation to Hypoxia in Sleep Apnea Patients: Multifaceted Mechanisms.
# Author name: Maryla Śmietanowska
# Author email: maciej.smietanowski@wum.edu.pl
# Author reference: Laboratory of Center for Preclinical Research, Department of Experimental and Clinical Physiology, First Faculty of Medicine, Warsaw Medical University, Warsaw, Poland. maciej.smietanowski@wum.edu.pl.
#
# Paper title: [Clinical consequences and economic costs of obstructive sleep apnea syndrome].
# No email addresses associated with this paper.
#
# Paper title: Sleep apnea, psychopathology, and mental health care.
# Author name: Christopher N Kaufmann
# Author email: cnkaufmann@ucsd.edu
# Author reference: Department of Psychiatry, UC San Diego, 9500 Gilman Drive, La Jolla, CA 92093, USA; Stein Institute for Research on Aging, UC San Diego, 9500 Gilman Drive, La Jolla, CA 92093, USA. Electronic address: cnkaufmann@ucsd.edu.
#
# Paper title: Activation of the Integrated Stress Response and Metabolic Dysfunction in a Murine Model of Sleep Apnea.
# No email addresses associated with this paper.
#
# Paper title: Decreased sL-selectin serum levels in sleep apnea syndrome patients with cardiovascular diseases.
# No email addresses associated with this paper.
#
# Paper title: Myofunctional Therapy to Treat Obstructive Sleep Apnea: A Systematic Review and Meta-analysis.
# No email addresses associated with this paper.
#
# Paper title: National patterns of physician management of sleep apnea and treatment among patients with hypertension.
# No email addresses associated with this paper.
#
# Paper title: Predictors of Sleep Apnea in the Canadian Population.
# No email addresses associated with this paper.
#
# Paper title: Patient Partnerships Transforming Sleep Medicine Research and Clinical Care: Perspectives from the Sleep Apnea Patient-Centered Outcomes Network.
# No email addresses associated with this paper.
#
# Paper title: Sleep Apnea, Disability Pensions, and Cause-Specific Mortality: A Swedish Nationwide Register Linkage Study.
# No email addresses associated with this paper.
#
# Paper title: The Association Between Sleep Apnea and Suicidal Thought and Behavior: An Analysis of National Survey Data.
# Author name: Todd M Bishop
# Author email: todd.bishop@va.gov
# Author reference: Center of Excellence for Suicide Prevention, Canandaigua VAMC, 400 Fort Hill Ave, Canandaigua, NY 14244. todd.bishop@va.gov.
#
# Paper title: Sleep Apnea and Sleep-Disordered Breathing.
# Author name: Maria Suurna
# Author email: mas9390@med.cornell.edu
# Author reference: Department of Otolaryngology-Head and Neck Surgery, Weill Cornell Medicine, New York Presbyterian Hospital, 1305 York Avenue, New York, NY 10021, USA. Electronic address: mas9390@med.cornell.edu.
#
# Paper title: The deterioration of driving performance over time in drivers with untreated sleep apnea.
# Author name: Jennifer F May
# Author email: jlfreema@sentara.com
# Author reference: Old Dominion University, Department of Psychology, Norfolk, VA, United States; Sentara Healthcare, Sleep Centers, Norfolk, VA, United States. Electronic address: jlfreema@sentara.com.
#
# Paper title: Obstructive Sleep Apnea in Heart Failure: Review of Prevalence, Treatment with Continuous Positive Airway Pressure, and Prognosis.
# No email addresses associated with this paper.
#
# Paper title: [Supine position and REM dependence in obstructive sleep apnea. Critical model considerations. German version].
# Author name: A Steffen
# Author email: armin.steffen@uksh.de
# Author reference: Klinik für Hals-, Nasen- und Ohrenheilkunde, Universitätsklinikum Schleswig-Holstein, Campus Lübeck, und Universität zu Lübeck, Ratzeburger Allee 160, 23538, Lübeck, Deutschland. armin.steffen@uksh.de.
#
# Paper title: Identifying individual sleep apnea/hypoapnea epochs using smartphone-based pulse oximetry.
# No email addresses associated with this paper.
#
# Paper title: Sleep apnea prevalence in chronic kidney disease - association with total body water and symptoms.
# Author name: Hsin-Chia Huang
# Author email: Richard.singer@act.gov.au
# Author reference: Department of Respiratory and Sleep Medicine, The Canberra Hospital, Garran, ACT, Australia. Richard.singer@act.gov.au.
#
# Paper title: Sex differences in sleep apnea and comorbid neurodegenerative diseases.
# Author name: Rebecca L Cunningham
# Author email: Rebecca.Cunningham@unthsc.edu
# Author reference: Department of Physiology and Anatomy, University of North Texas Health Science Center, Fort Worth, TX, United States. Electronic address: Rebecca.Cunningham@unthsc.edu.
#
# Paper title: Therapeutic Targeting of the Carotid Body for Treating Sleep Apnea in a Pre-clinical Mouse Model.
# Author name: Nanduri R Prabhakar
# Author email: nanduri@uchicago.edu
# Author reference: Institute for Integrative Physiology and Center for Systems Biology of Oxygen Sensing, Biological Sciences Division, University of Chicago, Chicago, IL, USA. nanduri@uchicago.edu.
#
# Paper title: Self-Reported Sleep Apnea and Dementia Risk: Findings from the Prevention of Alzheimer's Disease with Vitamin E and Selenium Trial.
# No email addresses associated with this paper.
#
# Paper title: The relationship between sleep apnea, metabolic dysfunction and inflammation: The gender influence.
# Author name: Monica L Andersen
# Author email: ml.andersen12@gmail.com
# Author reference: Department of Psychobiology, Universidade Federal de São Paulo, Rua Napoleão de Barros, 925, 04024-002 São Paulo, SP, Brazil. Electronic address: ml.andersen12@gmail.com.
#
# Paper title: Risk of tinnitus in patients with sleep apnea: A nationwide, population-based, case-control study.
# No email addresses associated with this paper.
#
# Paper title: Recognition of Sleep Apnea Is Increasing. Analysis of Trends in Two Large, Representative Databases of Outpatient Practice.
# No email addresses associated with this paper.
#
# Paper title: The effect of sleep apnea on all-cause mortality in nondialyzed chronic kidney disease patients.
# Author name: Ho Jun Chin
# Author email: mednep@hanmail.net
# Author reference: Department of Internal Medicine, Seoul National University Bundang Hospital, Seongnam, South Korea; Department of Internal Medicine, Seoul National University College of Medicine, Seoul, South Korea. Electronic address: mednep@hanmail.net.
#
# Paper title: Challenges in recruitment to a randomized controlled study of cardiovascular disease reduction in sleep apnea: an analysis of alternative strategies.
# No email addresses associated with this paper.
#
# Paper title: Sleep Apnea in Hurler Syndrome: Looking Beyond the Upper Airway.
# No email addresses associated with this paper.
#
# Paper title: Postoperative sleep-disordered breathing in patients without preoperative sleep apnea.
# No email addresses associated with this paper.
#
# Paper title: Sleep apnea: a review of diagnostic sensors, algorithms, and therapies.
# No email addresses associated with this paper.
#
# Paper title: Association between Drug-Induced Sleep Endoscopy and Measures of Sleep Apnea Burden.
# Author name: Raj C Dedhia
# Author email: raj.dedhia@emory.edu
# Author reference: Department of Otolaryngology, University of Washington School of Medicine, Seattle, Washington, USA Division of Pulmonary and Critical Care Medicine, University of Washington School of Medicine, Seattle, Washington, USA raj.dedhia@emory.edu.
#
# Paper title: Sleep Apnea and Idiopathic Leg Edema: A Case Control Study.
# No email addresses associated with this paper.
#
# Paper title: Assessing Whether the Association Between Sleep Apnea and Diabetes is Bidirectional.
# Author name: Chi-Shin Wu
# Author email: chishinwu@ntu.edu.tw
# Author reference: Department of Psychiatry, National Taiwan University Hospital and College of Medicine, National Taiwan University, Taipei, Taiwan; Department of Psychiatry, Far Eastern Memorial Hospital, New Taipei City, Taiwan. Electronic address: chishinwu@ntu.edu.tw.
#
# Paper title: Expiratory Time Constant and Sleep Apnea Severity in the Overlap Syndrome.
# No email addresses associated with this paper.
#
# Paper title: Pediatric sleep apnea and depressive disorders risk: A population-based 15-year retrospective cohort study.
# No email addresses associated with this paper.
#
# Paper title: Serum triglyceride levels in relation to high-density lipoprotein cholesterol (TG-HDL) ratios as an efficient tool to estimate the risk of sleep apnea syndrome in non-overweight Japanese men.
# Author name: Yuji Shimizu
# Author email: simizicyuu@yahoo.co.jp
# Author reference: Department of Community Medicine, Nagasaki University Graduate School of Biomedical Science, Nagasaki, Japan. simizicyuu@yahoo.co.jp.
#
# Paper title: Beyond type 2 diabetes, obesity and hypertension: an axis including sleep apnea, left ventricular hypertrophy, endothelial dysfunction, and aortic stiffness among Mexican Americans in Starr County, Texas.
# Author name: Craig L Hanis
# Author email: Craig.L.Hanis@uth.tmc.edu
# Author reference: Human Genetics Center, School of Public Health, The University of Texas Health Science Center at Houston, Houston, TX, 77225, USA. Craig.L.Hanis@uth.tmc.edu.
#
# Paper title: Real-time apnea-hypopnea event detection during sleep by convolutional neural networks.
# Author name: Kwang Suk Park
# Author email: pks@bmsil.snu.ac.kr
# Author reference: Department of Biomedical Engineering, College of Medicine, Seoul National University, South Korea. Electronic address: pks@bmsil.snu.ac.kr.
#
# Paper title: The utility of home sleep apnea tests in patients with low versus high pre-test probability for moderate to severe OSA.
# Author name: Cathy A Goldstein
# Author email: cathygo@med.umich.edu
# Author reference: Sleep Disorders Center, Department of Neurology, University of Michigan, 1500 East Medical Center Drive, Med Inn C728, Ann Arbor, MI, 48109, USA. cathygo@med.umich.edu.
#
# Paper title: Does Providing Positive Airway Pressure for Sleep Apnea Change Health Care Utilization?
# No email addresses associated with this paper.
#
# Paper title: Evaluation of a Multichannel Non-Contact ECG System and Signal Quality Algorithms for Sleep Apnea Detection and Monitoring.
# Author name: Ivan D Castro
# Author email: ivand.castro@imec.be
# Author reference: KU Leuven, Deptartment of Electrical Engineering-ESAT, 3001 Leuven, Belgium. ivand.castro@imec.be.
# Author name: Carolina Varon
# Author email: carolina.varon@esat.kuleuven.be
# Author reference: KU Leuven, Deptartment of Electrical Engineering-ESAT, 3001 Leuven, Belgium. carolina.varon@esat.kuleuven.be.
# Author name: Tom Torfs
# Author email: tom.torfs@imec.be
# Author reference: IMEC Belgium, 3001 Leuven, Belgium. tom.torfs@imec.be.
# Author name: Sabine Van Huffel
# Author email: sabine.vanhuffel@esat.kuleuven.be
# Author reference: KU Leuven, Deptartment of Electrical Engineering-ESAT, 3001 Leuven, Belgium. sabine.vanhuffel@esat.kuleuven.be.
# Author name: Robert Puers
# Author email: puers@esat.kuleuven.be
# Author reference: KU Leuven, Deptartment of Electrical Engineering-ESAT, 3001 Leuven, Belgium. puers@esat.kuleuven.be.
# Author name: Chris Van Hoof
# Author email: chris.vanhoof@imec.be
# Author reference: KU Leuven, Deptartment of Electrical Engineering-ESAT, 3001 Leuven, Belgium. chris.vanhoof@imec.be.
#
# Paper title: Pathway for the Management of Sleep Apnea in the Cardiac Patient.
# No email addresses associated with this paper.
#
# Paper title: Ovarian steroids act as respiratory stimulant and antioxidant against the causes and consequences of sleep-apnea in women.
# Author name: Vincent Joseph
# Author email: vincent.joseph@fmed.ulaval.ca
# Author reference: Centre de Recherche de l'Institut Universitaire de Cardiologie et de Pneumologie de Québec, Université Laval, Quebec City, Quebec, Canada. Electronic address: vincent.joseph@fmed.ulaval.ca.
#
# Paper title: Traditional and nontraditional cardiovascular risk factors in comorbid insomnia and sleep apnea.
# No email addresses associated with this paper.
#
# Paper title: Oxygen saturation, periodic breathing, and sleep apnea in infants aged 1-4 months old living at 3200 meters above sea level.
# Author name: Santiago Ucrós
# Author email: santiago_ucros@yahoo.com
# Author reference: Departamento de Pediatría, Fundación Santa Fe de Bogotá, Bogotá, Colombia. santiago_ucros@yahoo.com.
#
# Paper title: Relationship between obstructive sleep apnea and difficulty of anesthesia induction in children undergoing tonsillectomy.
# Author name: Swapna K Chandran
# Author email: sskart01@louisville.edu
# Author reference: Department of Otolaryngology-Head and Neck Surgery and Communicative Disorders, University of Louisville School of Medicine, Louisville, KY, USA. Electronic address: sskart01@louisville.edu.
#
# Paper title: Pediatric Sleep Apnea Syndrome: An Update.
# Author name: Jocelyn Celestin
# Author email: celestj@mail.amc.edu
# Author reference: Division of Allergy and Immunology, Department of Internal Medicine, Albany Medical College, Albany, NY. Electronic address: celestj@mail.amc.edu.
#
# Paper title: Sleep Apnea and Risk of Panic Disorder.
# Author name: Kun-Ta Chou
# Author email: ale1371@yahoo.com.tw
# Author reference: Center of Sleep Medicine, Taipei Veterans General Hospital, Taipei, Taiwan Department of Chest Medicine, Taipei Veterans General Hospital, Taipei, Taiwan School of Medicine, National Yang-Ming University, Taipei, Taiwan Institute of Clinical Medicine, School of Medicine, National Yang-Ming University, Taipei, Taiwan ale1371@yahoo.com.tw.
#
# Paper title: Assessing the severity of sleep apnea syndrome based on ballistocardiogram.
# No email addresses associated with this paper.
#
# Paper title: The Prevalence of Sleep Apnea in Type B Aortic Dissection: Implications for False Lumen Thrombosis.
# No email addresses associated with this paper.
#
# Paper title: Snoring Sounds Predict Obstruction Sites and Surgical Response in Patients with Obstructive Sleep Apnea Hypopnea Syndrome.
# No email addresses associated with this paper.
#
# Paper title: Ambulatory screening tool for sleep apnea: analyzing a single-lead electrocardiogram signal (ECG).
# Author name: Solveig Magnusdottir
# Author email: solveig.magnusdottir@sleepimage.com
# Author reference: MyCardio-LLC, SleepImage®, 370 Interlocken Blvd., Suite 650, Broomfield, CO, 80021, USA. solveig.magnusdottir@sleepimage.com.
#
# Paper title: Role of the Gut Microbiome in Obstructive Sleep Apnea-Induced Hypertension.
# Author name: David J Durgan
# Author email: durgan@bcm.edu
# Author reference: From the Departments of Anesthesiology (D.J.D., S.C.P., R.M.B.), Pathology and Immunology (B.P.G., J.L.C., E.B.H.), Molecular Physiology and Biophysics (R.M.B.), The Alkek Center for Metagenomics and Microbiome Research, Department of Molecular Virology and Microbiology (N.J.A., J.F.P.), and Texas Children's Microbiome Center, Department of Pathology, Baylor College of Medicine, Houston (J.L.C., E.B.H.); and Department of Medicine, Texas Children's Hospital, Houston (J.L.C., E.B.H.). durgan@bcm.edu.
#
# Paper title: The complex sleep apnea resolution study: a prospective randomized controlled trial of continuous positive airway pressure versus adaptive servoventilation therapy.
# No email addresses associated with this paper.
#
# Paper title: Desmin and dystrophin abnormalities in upper airway muscles of snorers and patients with sleep apnea.
# Author name: Per Stål
# Author email: per.stal@umu.se
# Author reference: Department of Integrative Medical Biology, Laboratory of Muscle Biology, Umeå University, SE-901 87, Umeå, Sweden. per.stal@umu.se.
#
# Paper title: Mandibular Advancement Appliance for Obstructive Sleep Apnea Treatment.
# Author name: J Kostrzewa-Janicka
# Author email: jolanta.kostrzewa-janicka@wum.edu.pl
# Author reference: Department of Prosthodontics, Medical University of Warsaw, Warsaw, Poland. jolanta.kostrzewa-janicka@wum.edu.pl.
#
# Paper title: 24-Hour Ambulatory Blood Pressure after Adenotonsillectomy in Childhood Sleep Apnea.
# Author name: Wei-Chung Hsu
# Author email: hsuwc@ntu.edu.tw
# Author reference: Department of Otolaryngology, National Taiwan University, College of Medicine and National Taiwan University Hospital, Taipei, Taiwan; Sleep Center, National Taiwan University Hospital, Taipei, Taiwan. Electronic address: hsuwc@ntu.edu.tw.
#
# Paper title: The relationships of sleep apnea, hypertension, and resistant hypertension on chronic kidney disease.
# No email addresses associated with this paper.
#
# Paper title: Sleep apnea in patients with chronic kidney disease: a single center experience.
# No email addresses associated with this paper.
#
# Paper title: Increased Urinary Erythropoietin Excretion in Severe Sleep Apnea-Hipoapnea Syndrome: The Effect of CPAP.
# Author name: Miquel Félez
# Author email: 91435@hospitaldelmar.cat
# Author reference: Unidad Multidisciplinar de Trastornos del Sueño, Hospital del Mar, Parc de Salut Mar, UAB-UPF, Barcelona, España; Servicio de Neumología, Hospital del Mar, Parc de Salut Mar, IMIM, UAB-UPF, CIBERES, ISC III, Barcelona, España. Electronic address: 91435@hospitaldelmar.cat.
#
# Paper title: Sleep Apnea and Hypertension: Are There Sex Differences? The Vitoria Sleep Cohort.
# Author name: Irene Cano-Pumarega
# Author email: irene.cano@yahoo.com
# Author reference: Respiratory Department, University Hospital of Getafe, Madrid, Spain; Universidad Europea de Madrid, Madrid, Spain. Electronic address: irene.cano@yahoo.com.
#
# Paper title: Sleep apnea syndrome, inflammation and oxidative stress in hemodialysis patients.
# No email addresses associated with this paper.
#
# Paper title: Differential likelihood of NSTEMI vs STEMI in patients with sleep apnea.
# Author name: Tomas Kara
# Author email: kara.tomas@mayo.edu
# Author reference: Department of Cardiovascular Diseases and International Clinical Research Center, St. Anne's University Hospital, Brno, Czech Republic; Department of Cardiovascular Diseases, Mayo Clinic and Mayo Foundation, Rochester, MN, United States; Department of Cardiovascular Diseases, Heart Hospital of Hamad Medical Corporation, Doha, Qatar; Center for Cardiovascular and Transplant Surgery Brno, Brno, Czech Republic. Electronic address: kara.tomas@mayo.edu.
#
# Paper title: A high risk of sleep apnea is associated with less postoperative cognitive dysfunction after intravenous anesthesia: results of an observational pilot study.
# Author name: Soeren Wagner
# Author email: so.wagner@klinikum-stuttgart.de
# Author reference: Department of Anesthesiology, University Hospital Erlangen, Friedrich-Alexander-University Erlangen-Nuremberg, Erlangen, Germany. so.wagner@klinikum-stuttgart.de.
#
# Paper title: Psoriasis and Sleep Apnea: A Danish Nationwide Cohort Study.
# No email addresses associated with this paper.
#
# Paper title: [Sleep Apnea].
# No email addresses associated with this paper.
#
# Paper title: Gender Differences in the Clinical Features of Sleep Apnea Syndrome.
# No email addresses associated with this paper.
#
# Paper title: Patients presenting to a Men's Health clinic are at higher risk for depression, insomnia, and sleep apnea.
# Author name: Faysal A Yafi
# Author email: faysalyafi@gmail.com
# Author reference: Department of Urology, University of California-Irvine, Irvine, CA, USA. faysalyafi@gmail.com.
#
# Paper title: An Intelligent Sleep Apnea Classification System Based on EEG Signals.
# Author name: V Vimala
# Author email: vimlaiswarya@gmail.com
# Author reference: Department of Computer Science and Engineering, Chennai Institute of Technology, Kundrathur, Chennai, Tamil Nadu, India. vimlaiswarya@gmail.com.
#
# Paper title: Biomarker panel in sleep apnea patients after an acute coronary event.
# Author name: Josep Miquel Bauça
# Author email: pepmiquel@gmail.com
# Author reference: Department of Laboratory Medicine, Hospital Universitari Son Espases, Palma, Balearic Islands, Spain; Institut d'Investigació Sanitària de les Illes Balears (IdISBa), Balearic Islands, Spain. Electronic address: pepmiquel@gmail.com.
#
# Paper title: Timely diagnosis and treatment of sleep apnea reduce cardiovascular sequelae in patients with myocardial infarction.
# No email addresses associated with this paper.
#
# Paper title: The treatment of central sleep apnea syndromes in adults: practice parameters with an evidence-based literature review and meta-analyses.
# No email addresses associated with this paper.
#
# Paper title: Acute exacerbation of sleep apnea by hyperoxia impairs cognitive flexibility in Brown-Norway rats.
# No email addresses associated with this paper.
#
# Paper title: Comparison of the Efficacy, Side Effects, and Cost of Modafinil and Intranasal Mometasone Furoate in Obstructive Sleep Apnea-Hypopnea Syndrome: A Preliminary Clinical Study.
# No email addresses associated with this paper.
#
# Paper title: Prevalence of sleep apnoea and capnographic detection of nocturnal hypoventilation in amyotrophic lateral sclerosis.
# No email addresses associated with this paper.
#
# Paper title: Sleep Apnea Screening Practices During Department of Transportation Medical Examinations.
# No email addresses associated with this paper.
#
# Paper title: Comorbidities and risk of mortality in patients with sleep apnea.
# No email addresses associated with this paper.
#
# Paper title: Data-Driven Multimodal Sleep Apnea Events Detection : Synchrosquezing Transform Processing and Riemannian Geometry Classification Approaches.
# Author name: Tomasz M Rutkowski
# Author email: tomek@bci-lab.info
# Author reference: Life Science Center of TARA University of Tsukuba, Tennodai 1-1-1, Tsukuba-shi, Ibaraki, Japan, 305-8577. tomek@bci-lab.info.
#
# Paper title: Clinical Predictors of Residual Sleep Apnea after Weight Loss Therapy in Obese Adolescents.
# Author name: Annelies Van Eyck
# Author email: Annelies.vaneyck@uantwerpen.be
# Author reference: Laboratory of Experimental Medicine and Pediatrics, University of Antwerp, Antwerp, Belgium; Department of Pediatrics, Antwerp University Hospital, Edegem, Belgium. Electronic address: Annelies.vaneyck@uantwerpen.be.
#
# Paper title: Unattended Hospital and Home Sleep Apnea Testing Following Cerebrovascular Events.
# Author name: Mark I Boulos
# Author email: mark.boulos@sunnybrook.ca
# ...
# Author name: Henrik Hack
# Author email: henrikh@adhb.govt.nz
# Author reference: Department of Paediatric Anaesthesia, Royal Manchester Children's Hospital, Manchester, UK. Electronic address: henrikh@adhb.govt.nz.
#
# Paper title: On the edge between medicine and dentistry: review of the dentist's role in the diagnosis and treatment of snoring and sleep apnea.
# No email addresses associated with this paper.
#
# Paper title: Revise Respiratory Event Criteria or Revise Severity Thresholds for Sleep Apnea Definition?
# No email addresses associated with this paper.
#
# Paper title: Burden of sleep apnea: rationale, design, and major findings of the Wisconsin Sleep Cohort study.
# Author name: Terry Young
# Author email: tbyoung@wisc.edu
# Author reference: Department of Population Health Sciences, School of Medicine and Public Health, University of Wisconsin-Madison, Madison, WI 53706, USA. tbyoung@wisc.edu
#
# Paper title: Approach to outpatient management of adult sleep apnea.
# Author name: Neil M Skjodt
# Author email: neil.skjodt@ualberta.ca
# Author reference: neil.skjodt@ualberta.ca
#
# Paper title: Periodic limb movements in sleep revealed by treatment of sleep apnea with continuous positive airway pressure in the advanced chronic kidney disease population.
# Author name: R L Benz
# Author email: bobbenz@gmail.com
# Author reference: Division of Nephrology, Lankenau Medical Center, Wynnewood, PA 19096, USA. bobbenz@gmail.com
#
# Paper title: Respiratory polygraphy for follow-up of obstructive sleep apnea in children.
# Author name: María Luz Alonso-Álvarez
# Author email: mlalonso@hgy.es
# Author reference: Sleep Unit, Complejo Asistencial Universitario de Burgos, Burgos, Spain. mlalonso@hgy.es
#
# Paper title: Sleep apnea in patients with heart failure: could cardiac resynchronization therapy be the first line treatment?
# No email addresses associated with this paper.
#
# Paper title: Sleep apnea, cardiac arrhythmias, and conduction disorders.
# Author name: Adrian Baranchuk
# Author email: barancha@kgh.kari.net
# Author reference: Cardiology Division, Kingston General Hospital, Queen's University, Kingston, Ontario, Canada. barancha@kgh.kari.net
#
# Paper title: Nurse Practitioners and Physician Assistants Are Qualified to Perform Home Sleep Apnea Test Clinical Evaluations.
# No email addresses associated with this paper.
#
# Paper title: Changes in lung volume and diaphragm muscle activity at sleep onset in obese obstructive sleep apnea patients vs. healthy-weight controls.
# Author name: Daniel L Stadler
# Author email: daniel.stadler@health.sa.gov.au
# Author reference: Adelaide Institute for Sleep Health, Repatriation General Hospital, Daw Park, South Australia 5041, Australia. daniel.stadler@health.sa.gov.au
#
# Paper title: Sleep apnea: implications for heart failure.
# Author name: Lyle J Olson
# Author email: olson.lyle@mayo.edu
# Author reference: Department of Internal Medicine, Mayo Clinic College of Medicine, 200 First Street SW, Rochester, MN 55905, USA. olson.lyle@mayo.edu
#
# Paper title: Sleep-Disordered Breathing and Excessive Daytime Sleepiness.
# No email addresses associated with this paper.
#
# Paper title: Morphometric endoscopic study of the pharynx in patients with sleep apnea.
# No email addresses associated with this paper.
#
# Paper title: Epidemiology of Sleep-Disordered Breathing and Heart Failure: What Drives What.
# Author name: Lee K Brown
# Author email: lkbrown@alum.mit.edu
# Author reference: Division of Pulmonary, Critical Care, and Sleep Medicine, Department of Internal Medicine, University of New Mexico School of Medicine, 1101 Medical Arts Avenue NE, Building #2, Albuquerque, NM, 87102, USA. lkbrown@alum.mit.edu.
#
# Paper title: Screening for sleep apnea in the perioperative setting: looking for the right compromise.
# Author name: Tanaya Sparkle
# Author email: davide.cattano@uth.tmc.edu
# Author reference: Department of Anesthesiology, University of Texas Medical School, Memorial Hermann Hospital, Texas Medical Center, Houston, TX, USA - davide.cattano@uth.tmc.edu.
#
# Paper title: Noradrenergic control of trigeminal motoneurons in sleep: relevance to sleep apnea.
# Author name: Peter B Schwarz
# Author email: p.schwarz@utoronto.ca
# Author reference: Cell and Systems Biology, University of Toronto, Toronto, Ontario, Canada. p.schwarz@utoronto.ca
#
# Paper title: Impact of SERVE-HF on management of sleep disordered breathing in heart failure: a call for further studies.
# Author name: Dominik Linz
# Author email: dominik.linz@uks.eu
# Author reference: Klinik für Innere Medizin III, Kardiologie, Angiologie und Internistische Intensivmedizin, Universitätsklinikum des Saarlandes, Kirrberger Strasse 1, Geb. 40, 66421, Homburg, Saarland, Germany. dominik.linz@uks.eu.
#
# Paper title: [Cardiovascular risk of sleep apnoea and case report].
# No email addresses associated with this paper.
#
# Paper title: The challenges of advancing the evidence for the long-term effectiveness of oral appliance therapy for sleep apnea.
# Author name: Olivier M Vanderveken
# Author email: olivier.vanderveken@uza.be
# Author reference: Faculty of Medicine and Health Sciences, University of Antwerp, Edegem, Belgium; Department ENT, Head and Neck Surgery, Antwerp University Hospital, Wilrijkstraat 10, BE-2650 Edegem, Belgium. Electronic address: olivier.vanderveken@uza.be.
#
# Paper title: Long-term changes in neurocognition and behavior following treatment of sleep disordered breathing in school-aged children.
# No email addresses associated with this paper.
#
# Paper title: Serum gamma glutamyl transferase in patients with sleep apnea-hypopnea.
# Author name: Tomoyuki Kawada
# Author email: kawada@nms.ac.jp
# Author reference: Department of Hygiene and Public Health, Nippon Medical School, 1-1-5 Sendagi, Bunkyo-Ku, Tokyo, 113-8602, Japan. kawada@nms.ac.jp.
#
# Paper title: Atrial fibrillation and obstructive sleep apnea: something more than a coincidence.
# Author name: Miguel A Arias
# Author email: maapalomares@secardiologia.es
# Author reference: Unidad de Arritmias y Electrofisiología Cardiaca, Servicio de Cardiología, Hospital Virgen de la Salud, Toledo, Spain. Electronic address: maapalomares@secardiologia.es.
#
# Paper title: Social and Economic Impacts of Managing Sleep Hypoventilation Syndromes.
# Author name: Dianne M Augelli
# Author email: dma9013@med.cornell.edu
# Author reference: Department of Medicine, Center for Sleep Medicine, Weill Cornell Medical College, Cornell University, 425 East 61st Street, 5th Floor, New York, NY 10065, USA. Electronic address: dma9013@med.cornell.edu.
#
# Paper title: Asthma and obstructive sleep apnea: clinical and pathogenic interactions.
# No email addresses associated with this paper.
#
# Paper title: Longitudinal Cardiovascular Outcomes of Sleep Disordered Breathing in Children: A Meta-Analysis and Systematic Review.
# No email addresses associated with this paper.
#
# Paper title: Usefulness of extended holter ECG monitoring for serious arrhythmia detection in patients with heart failure and sleep apnea.
# Author name: Barbara Uznańska-Loch
# Author email: tyhe@op.pl
# Author reference: Chair and Clinic of Cardiology, Medical University of Łódź, Łódź, 91-347 Poland. tyhe@op.pl
#
# Paper title: Upper airway dimensions in patients with craniocervical junction malformations with and without sleep apnea. A pilot case-control study.
# No email addresses associated with this paper.
#
# Paper title: Apnea-hypopnea index in sleep studies and the risk of over-simplification.
# No email addresses associated with this paper.
#
# Paper title: Autonomic nervous system and cardiac channelopathies in sleep apnea-one more piece of a complex puzzle?
# Author name: Steiner Stephan
# Author email: s.steiner@st-vincenz.de
# Author reference: Department of Medicine, Division of Cardiology, Pneumology and Intensive Care Medicine, St. Vincenz Hospital, Auf dem Schafsberg, 65549, Limburg/Lahn, Germany. s.steiner@st-vincenz.de.
#
# Paper title: Effects of sleep apnea syndrome on delayed memory and executive function in elderly adults.
# No email addresses associated with this paper.
#
# Paper title: Obstructive sleep apnea in children: implications for the developing central nervous system.
# Author name: David Gozal
# Author email: david.gozal@louisville.edu
# Author reference: Kosair Children's Hospital Research Institute and Division of Pediatric Sleep Medicine, Department of Pediatrics, University of Louisville School of Medicine, Louisville, KY 40202, USA. david.gozal@louisville.edu
#
# Paper title: The impact of sleep apnea on postoperative utilization of resources and adverse outcomes.
# No email addresses associated with this paper.
#
# Paper title: Association of allergy/immunology and obstructive sleep apnea.
# No email addresses associated with this paper.
#
# Paper title: The coagulation and protein C pathways in patients with sleep apnea.
# No email addresses associated with this paper.
#
# Paper title: Comparative effectiveness research in complex sleep apnea.
# No email addresses associated with this paper.
#
# Paper title: Poincaré analysis of an overnight arterial oxygen saturation signal applied to the diagnosis of sleep apnea hypopnea syndrome.
# Author name: Daniel S Morillo
# Author email: daniel.morillo@uca.es
# Author reference: Biomedical Engineering and Telemedicine Researching Group (IBT), University of Cádiz, and Pneumology Department of Hospital Universitario Puerta del Mar de Cádiz, Cádiz, Spain. daniel.morillo@uca.es
#
# Paper title: Assessment of screening tests for sleep apnea syndrome in the workplace.
# Author name: Shigemi Tanaka
# Author email: 7787may@kcc.zaq.ne.jp
# Author reference: Tanaka Internal Medicine Clinic, Department of Public Health, Hyogo College of Medicine, Nishinomiya, Hyogo, Japan. 7787may@kcc.zaq.ne.jp
#
# Paper title: In reply: Perioperative nocturnal hypoxemia matters in surgical patients with obstructive sleep apnea.
# Author name: Eric Deflandre
# Author email: eric.deflandre@gmail.com
# Author reference: Department of Anesthesia, Clinique Saint-Luc of Bouge, Namur, Belgium. eric.deflandre@gmail.com.
#
# Paper title: Monitoring torso acceleration for estimating the respiratory flow and efforts for sleep apnea detection.
# Author name: Parastoo Dehkordi
# Author email: pdehkord@sfu.ca
# Author reference: CiBER Lab, School of Engineering Science, Simon Fraser University, Burnaby, BC V5A 1S6 Canada. pdehkord@sfu.ca
#
# Paper title: Managing the Child with Persistent Sleep Apnea.
# Author name: Cristina M Baldassari
# Author email: baldassc@gmail.com
# Author reference: Department of Otolaryngology-Head and Neck Surgery, Eastern Virginia Medical School, 600 Gresham Drive, Suite 1100, Norfolk, VA 23507, USA; Departments of Pediatric Otolaryngology and Pediatric Sleep Medicine, Children's Hospital of the King's Daughters, 601 Children's Lane, 2nd Floor, Norfolk, VA 23507, USA. Electronic address: baldassc@gmail.com.
#
# Paper title: Carotid body chemoreflex: a driver of autonomic abnormalities in sleep apnoea.
# No email addresses associated with this paper.
#
# Paper title: Trilevel adaptive servoventilation for the treatment of central and mixed sleep apnea in chronic heart failure patients.
# Author name: Olaf Oldenburg
# Author email: akleemeyer@hdz-nrw.de
# Author reference: Dept. of Cardiology, Heart and Diabetes Centre North Rhine Westphalia, Ruhr University Bochum, Bad Oeynhausen, Germany. akleemeyer@hdz-nrw.de
#
# Paper title: Racial/Ethnic Differences in Sleep Disturbances: The Multi-Ethnic Study of Atherosclerosis (MESA).
# No email addresses associated with this paper.
#
# Paper title: [Guidelines in Practice: The New S3 Guideline "Sleeping Disorders - Sleep-Related Abnormal Breathing"].
# No email addresses associated with this paper.
#
# Paper title: Sleep Apnea in Patients With Rett Syndrome: Roles for Polysomnography and Adenotonsillectomy.
# No email addresses associated with this paper.
#
# Paper title: Sleep apnea is induced by a high-fat diet and reversed and prevented by metformin in non-obese rats.
# Author name: Wiâm Ramadan
# Author email: wiam.ramadan@etud.u-picardie.fr
# Author reference: EA 3901, Dysrégulations Métaboliques Acquises et Génétiques, Université de Picardie Jules Verne, Faculté de Médecine, 3 Rue des Louvels, F-80036 Amiens cedex 1, France. wiam.ramadan@etud.u-picardie.fr
#
# Paper title: Contemporary outcomes of optimally treated heart failure patients with sleep apnea. Case for urgency in evaluation of newer interventions? From the Atlanta Cardiomyopathy Consortium.
# No email addresses associated with this paper.
#
# Paper title: Diabetes mellitus prevalence and control in sleep-disordered breathing: the European Sleep Apnea Cohort (ESADA) study.
# Author name: Walter T McNicholas
# Author email: Walter.mcnicholas@ucd.ie
# Author reference: School of Medicine and Medical Science, University College Dublin and Pulmonary and Sleep Disorders Unit, St. Vincent's University Hospital, Dublin, Ireland. Electronic address: Walter.mcnicholas@ucd.ie.
#
# Paper title: Novel and emerging nonpositive airway pressure therapies for sleep apnea.
# Author name: John G Park
# Author email: park.john@mayo.edu
# Author reference: Mayo Clinic College of Medicine, Rochester, MN. Electronic address: park.john@mayo.edu.
#
# Paper title: All night analysis of time interval between snores in subjects with sleep apnea hypopnea syndrome.
# Author name: J Mesquita
# Author email: jmesquita@ibecbarcelona.eu
# Author reference: Department ESAII, Universitat Politècnica de Catalunya, Barcelona, Spain. jmesquita@ibecbarcelona.eu
#
# Paper title: Adenotonsillectomy for childhood obstructive sleep apnoea reduces thoraco-abdominal asynchrony but spontaneous apnoea-hypopnoea index normalisation does not.
# Author name: Mathias Baumert
# Author email: mathias.baumert@adelaide.edu.au
# Author reference: School of Electrical and Electronic Engineering, The University of Adelaide, Adelaide, Australia mathias.baumert@adelaide.edu.au.
#
# Paper title: Screening for obstructive sleep apnea in children with syndromic cleft lip and/or palate.
# Author name: Jesse A Taylor
# Author email: Taylorj5@email.chop.edu
# Author reference: Division of Plastic Surgery, The Perelman School of Medicine at the University of Pennsylvania, The Children's Hospital of Philadelphia, USA. Electronic address: Taylorj5@email.chop.edu.
#
# Paper title: Effects of exercise training on sleep apnoea in patients with coronary artery disease: a randomised trial.
# Author name: T Douglas Bradley
# Author email: douglas.bradley@utoronto.ca
# Author reference: Sleep Research Laboratory, University Health Network Toronto Rehabilitation Institute, Toronto, ON, Canada Centre for Sleep Medicine and Circadian Biology, University of Toronto, Toronto, ON, Canada Dept of Medicine, University Health Network, Toronto General Hospital, Toronto, ON, Canada douglas.bradley@utoronto.ca.
#
# Paper title: Frequency of snoring, rather than apnea-hypopnea index, predicts both cognitive and behavioral problems in young children.
# Author name: Dale L Smith
# Author email: dsmith8@olivet.edu
# Author reference: Department of Public Health Sciences, The University of Chicago, Chicago, IL, USA; Department of Psychology, Olivet Nazarene University, Bourbonnais, IL, USA. Electronic address: dsmith8@olivet.edu.
#
# Search complete.
#
# Searching PubMed for papers about RHEUMATOLOGY near OXFORD...
#
# Paper title: Are the 1990 American College of Rheumatology vasculitis classification criteria still valid?
# No email addresses associated with this paper.
#
# Paper title: Group for Research and Assessment of Psoriasis and Psoriatic Arthritis/Outcome Measures in Rheumatology Consensus-Based Recommendations and Research Agenda for Use of Composite Measures and Treatment Targets in Psoriatic Arthritis.
# No email addresses associated with this paper.
#
# Paper title: Perspectives From Masters in Rheumatology and Autoimmunity: Can We Get Closer to a Cure for Rheumatoid Arthritis?
# No email addresses associated with this paper.
#
# Search complete.
#
# ALL SEARCHES COMPLETE
# Results written to c:\users\ben\documents\code\python\pubmed\pubmed_emails.csv
